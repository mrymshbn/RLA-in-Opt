# %%
import scipy
import random
import portpy.photon as pp
import numpy as np
from cvxpy import *
from scipy import sparse
import sklearn.metrics
import cProfile
import time
import sys
import psutil
from sklearn.decomposition import PCA
import cvxpy as cp
import matplotlib.pyplot as plt

# %%
data_dir = r'../Data'
data = pp.DataExplorer(data_dir=data_dir)
patient_id = 'Lung_Phantom_Patient_1'
data.patient_id = patient_id
ct = pp.CT(data)
structs = pp.Structures(data)
beams = pp.Beams(data)
opt_params = data.load_config_opt_params(protocol_name='Lung_2Gy_30Fx')
structs.create_opt_structures(opt_params)
inf_matrix_sparse = pp.InfluenceMatrix(ct=ct, structs=structs, beams=beams)
protocol_name = 'Lung_2Gy_30Fx'
clinical_criteria = pp.ClinicalCriteria(data, protocol_name)
plan_sparse = pp.Plan(ct, structs, beams, inf_matrix_sparse, clinical_criteria)
opt = pp.Optimization(plan_sparse, opt_params=opt_params)

opt.create_cvxpy_problem()
time_sprs = time.time()
sol_sparse = opt.solve(solver='MOSEK', verbose=True)
print(time.time()- time_sprs)
dose_sparse_1d = plan_sparse.inf_matrix.A @ (sol_sparse['optimal_intensity'] * plan_sparse.get_num_of_fractions())
x_sparse =sol_sparse['optimal_intensity'] * plan_sparse.get_num_of_fractions()
beams_full = pp.Beams(data, load_inf_matrix_full=True)
inf_matrix_full = pp.InfluenceMatrix(ct=ct, structs=structs, beams=beams_full, is_full=True)
plan_full = pp.Plan(ct, structs, beams_full, inf_matrix_full, clinical_criteria)
dose_full_1d = plan_full.inf_matrix.A @ (sol_sparse['optimal_intensity'] * plan_full.get_num_of_fractions())
A_full = plan_full.inf_matrix.A
# A_full_csr = sparse.csr_matrix(A_full)
A_sparse = plan_sparse.inf_matrix.A
sparse_tol = plan_sparse.inf_matrix.sparse_tol
#print(sol_sparse['problem_value'])
# Out:
# creating rinds.. This step may take some time due to dilation
# rinds created!!
# Creating BEV..
# Loading sparse influence matrix...
# Done
# Objective Start
# Objective done
# Constraints Start
# Structure ESOPHAGUS not available!
# Structure ESOPHAGUS not available!
# Constraints done
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Jan 27 08:30:00 PM: Your problem has 1946 variables, 14 constraints, and 0 parameters.
# (CVXPY) Jan 27 08:30:00 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 27 08:30:00 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 27 08:30:00 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 27 08:30:00 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 27 08:30:00 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Jan 27 08:30:00 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Jan 27 08:30:00 PM: Applying reduction Dcp2Cone
# (CVXPY) Jan 27 08:30:00 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 27 08:30:00 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jan 27 08:30:01 PM: Applying reduction MOSEK
# (CVXPY) Jan 27 08:30:01 PM: Finished problem compilation (took 1.351e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 27 08:30:01 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Jan 27 08:30:02 PM: Problem
# (CVXPY) Jan 27 08:30:02 PM:   Name                   :
# (CVXPY) Jan 27 08:30:02 PM:   Objective sense        : maximize
# (CVXPY) Jan 27 08:30:02 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Jan 27 08:30:02 PM:   Constraints            : 1959
# (CVXPY) Jan 27 08:30:02 PM:   Affine conic cons.     : 0
# (CVXPY) Jan 27 08:30:02 PM:   Disjunctive cons.      : 0
# (CVXPY) Jan 27 08:30:02 PM:   Cones                  : 13
# (CVXPY) Jan 27 08:30:02 PM:   Scalar variables       : 215748
# (CVXPY) Jan 27 08:30:02 PM:   Matrix variables       : 0
# (CVXPY) Jan 27 08:30:02 PM:   Integer variables      : 0
# (CVXPY) Jan 27 08:30:02 PM:
# (CVXPY) Jan 27 08:30:02 PM: Optimizer started.
# (CVXPY) Jan 27 08:30:02 PM: Presolve started.
# (CVXPY) Jan 27 08:30:02 PM: Linear dependency checker started.
# (CVXPY) Jan 27 08:30:02 PM: Linear dependency checker terminated.
# (CVXPY) Jan 27 08:30:02 PM: Eliminator started.
# (CVXPY) Jan 27 08:30:02 PM: Freed constraints in eliminator : 0
# (CVXPY) Jan 27 08:30:02 PM: Eliminator terminated.
# (CVXPY) Jan 27 08:30:02 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY)
# (CVXPY) Jan 27 08:30:03 PM: 13  1.3e-03  2.1e-03  2.1e-06  9.99e-01   4.251789703e+01   4.251835713e+01   9.3e-06  1.19
# (CVXPY) Jan 27 08:30:03 PM: 14  4.8e-04  7.9e-04  4.9e-07  9.99e-01   4.220398675e+01   4.220415345e+01   3.4e-06  1.24
# (CVXPY) Jan 27 08:30:03 PM: 15  1.1e-04  1.7e-04  5.0e-08  1.00e+00   4.207786875e+01   4.207790502e+01   7.5e-07  1.28
# (CVXPY) Jan 27 08:30:03 PM: 16  6.0e-06  9.7e-06  6.2e-10  1.00e+00   4.204776570e+01   4.204776790e+01   4.2e-08  1.33
# (CVXPY) Jan 27 08:30:03 PM: 17  3.1e-06  8.5e-05  2.3e-10  9.71e-01   4.204640004e+01   4.204640115e+01   2.1e-08  1.38
# (CVXPY) Jan 27 08:30:03 PM: 18  1.6e-06  4.5e-05  9.2e-11  9.98e-01   4.204593607e+01   4.204593666e+01   1.1e-08  1.42
# (CVXPY) Jan 27 08:30:03 PM: 19  7.9e-07  2.2e-05  3.2e-11  9.96e-01   4.204558734e+01   4.204558762e+01   5.5e-09  1.47
# (CVXPY) Jan 27 08:30:03 PM: 20  2.9e-07  8.1e-06  7.2e-12  9.84e-01   4.204545489e+01   4.204545499e+01   2.0e-09  1.52
# (CVXPY) Jan 27 08:30:04 PM: 21  9.4e-08  2.6e-06  1.3e-12  9.93e-01   4.204539003e+01   4.204539006e+01   6.5e-10  1.61
# (CVXPY) Jan 27 08:30:04 PM: Optimizer terminated. Time: 1.66
# (CVXPY) Jan 27 08:30:04 PM:
# (CVXPY) Jan 27 08:30:04 PM:
# (CVXPY) Jan 27 08:30:04 PM: Interior-point solution summary
# (CVXPY) Jan 27 08:30:04 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Jan 27 08:30:04 PM:   Solution status : OPTIMAL
# (CVXPY) Jan 27 08:30:04 PM:   Primal.  obj: 4.2045390026e+01    nrm: 1e+02    Viol.  con: 2e-06    var: 5e-07    cones: 0e+00
# (CVXPY) Jan 27 08:30:04 PM:   Dual.    obj: 4.2045390059e+01    nrm: 6e+03    Viol.  con: 0e+00    var: 9e-09    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 27 08:30:04 PM: Problem status: optimal
# (CVXPY) Jan 27 08:30:04 PM: Optimal value: 4.205e+01
# (CVXPY) Jan 27 08:30:04 PM: Compilation took 1.351e+00 seconds
# (CVXPY) Jan 27 08:30:04 PM: Solver (including time spent in interface) took 2.203e+00 seconds
# 3.6144800186157227
# Creating BEV..
# Loading full influence matrix..
# Done

# %%
A_full = plan_full.inf_matrix.A
A_sparse = plan_sparse.inf_matrix.A


sparse_tol = plan_sparse.inf_matrix.sparse_tol

A_full[A_full <= sparse_tol] = 0
test = np.abs(A_full - A_sparse.todense()) <= 1e-3

assert test.all()

# %%
S = A_sparse.transpose()
A = A_full
d = dose_full_1d
print(f'S = {S.shape}\nA = {A.shape}\nd = {d.shape}')

sol_ls_A_sparse = scipy.sparse.linalg.lsqr(S@A, S@d)
x_sparse_1 = sol_ls_A_sparse[0]


sol_ls_A_full = scipy.sparse.linalg.lsqr(A_full, dose_full_1d)
x_A_full_1 = sol_ls_A_full[0]
# Out:
# S = (542, 60183)
# A = (60183, 542)
# d = (60183,)

# %%
opt = pp.Optimization(plan_full, opt_params=opt_params)
opt.create_cvxpy_problem()

sol_full = opt.solve(solver='MOSEK', verbose=False)

x_full = sol_full['optimal_intensity'] * plan_full.get_num_of_fractions()
# Out:
# Objective Start
# Objective done
# Constraints Start
# Structure ESOPHAGUS not available!
# Structure ESOPHAGUS not available!
# Constraints done

# %%
# 

dose_full = plan_full.inf_matrix.A @ x_full
dose_sparse = plan_full.inf_matrix.A @ x_sparse_1


fig, ax = plt.subplots(figsize=(7, 5))
struct_names = ['PTV', 'ESOPHAGUS', 'HEART', 'CORD']
ax = pp.Visualization.plot_dvh(plan_full, dose_1d=dose_sparse, struct_names=struct_names, style='solid', ax=ax)
ax = pp.Visualization.plot_dvh(plan_full, dose_1d=dose_full, struct_names=struct_names, style='dotted', ax=ax)
ax.set_title('-  PortPy Sparse  .. Full ')
plt.show()
print('Done!')
# Out:
# Done!

# %%
opt = pp.Optimization(plan_full, opt_params=opt_params)
opt.create_cvxpy_problem()

sol= opt.solve(solver='MOSEK', verbose=False)
# Out:
# Objective Start
# Objective done
# Constraints Start
# Structure ESOPHAGUS not available!
# Structure ESOPHAGUS not available!
# Constraints done

# %%
# ایجاد یک تاپل جدید با مقادیر صحیح
new_sol_ls_A_sparse = (int(value) for value in sol_ls_A_sparse)

# یا ایجاد یک لیست جدید با مقادیر صحیح
# new_sol_ls_A_sparse = [int(value) for value in sol_ls_A_sparse]

# نمایش معیارهای بالینی با استفاده از تاپل یا لیست جدید
pp.Evaluation.display_clinical_criteria(plan_full, sol=new_sol_ls_A_sparse)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 8
#       2 new_sol_ls_A_sparse = (int(value) for value in sol_ls_A_sparse)
#       4 # یا ایجاد یک لیست جدید با مقادیر صحیح
#       5 # new_sol_ls_A_sparse = [int(value) for value in sol_ls_A_sparse]
#       6
#       7 # نمایش معیارهای بالینی با استفاده از تاپل یا لیست جدید
# ----> 8 pp.Evaluation.display_clinical_criteria(plan_full, sol=new_sol_ls_A_sparse)
#
# File ~\Desktop\PortPy\PortPy-master_old\portpy\photon\evaluation.py:85, in Evaluation.display_clinical_criteria(my_plan, sol, html_file_name, sol_names, clinical_criteria, return_df, in_browser)
#      83     sol = [sol]
#      84 if sol_names is None:
# ---> 85     if len(sol) > 1:
#      86         sol_names = ['Plan Value ' + str(i) for i in range(len(sol))]
#      87     else:
#
# TypeError: object of type 'generator' has no len()

# %%
# visualize plan metrics based upon clinical criteria
pp.Evaluation.display_clinical_criteria(plan_full, sol=sol_ls_A_sparse)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # visualize plan metrics based upon clinical criteria
# ----> 2 pp.Evaluation.display_clinical_criteria(plan_full, sol=sol_ls_A_sparse)
#
# File ~\Desktop\PortPy\PortPy-master_old\portpy\photon\evaluation.py:90, in Evaluation.display_clinical_criteria(my_plan, sol, html_file_name, sol_names, clinical_criteria, return_df, in_browser)
#      88         sol_names = ['Plan Value']
#      89 for p, s in enumerate(sol):
# ---> 90     dose_1d = s['inf_matrix'].A @ (s['optimal_intensity'] * my_plan.get_num_of_fractions())
#      91     for ind in range(len(df)):  # Loop through the clinical criteria
#      92         if df.name[ind] == 'max_dose':
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# plot fluence 3d and 2d for the 1st beam
pp.Visualization.plot_fluence_3d(sol=sol_sparse, beam_id=plan_sparse.beams.get_all_beam_ids()[1])

pp.Visualization.plot_fluence_2d(sol=sol_sparse, beam_id=plan_sparse.beams.get_all_beam_ids()[0])
# Out:
# <Axes: xlabel='x-axis (beamlets column)', ylabel='y-axis (beamlets row)'>

# %%
# plot 2d axial slice for the given solution and display the structures contours on the slice
pp.Visualization.plot_2d_slice(my_plan=plan_full, sol=sol_sparse, slice_num=60, struct_names=['PTV'])
# Out:
# <Axes: title={'center': 'Axial View - Slice #: 60'}>
