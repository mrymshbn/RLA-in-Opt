# %%
# import libraries

import scipy
import random
import portpy.photon as pp
import numpy as np
from cvxpy import *
from scipy import sparse
import sklearn.metrics
import cProfile
import time
import sys
import psutil
from sklearn.decomposition import PCA
from scipy.linalg import hadamard
import matplotlib.pyplot as plt
import cvxpy as cp

# %%
# import DataSet

data_dir = r'../data'
data = pp.DataExplorer(data_dir=data_dir)
patient_id = 'Lung_Phantom_Patient_1'
data.patient_id = patient_id
ct = pp.CT(data)
structs = pp.Structures(data)
beams = pp.Beams(data)
opt_params = data.load_config_opt_params(protocol_name='Lung_2Gy_30Fx')
structs.create_opt_structures(opt_params)
inf_matrix_sparse = pp.InfluenceMatrix(ct=ct, structs=structs, beams=beams)
protocol_name = 'Lung_2Gy_30Fx'
clinical_criteria = pp.ClinicalCriteria(data, protocol_name)
plan_sparse = pp.Plan(ct, structs, beams, inf_matrix_sparse, clinical_criteria)
opt = pp.Optimization(plan_sparse, opt_params=opt_params)
opt.create_cvxpy_problem()

sol_sparse = opt.solve(solver='MOSEK', verbose=True)
dose_sparse_1d = plan_sparse.inf_matrix.A @ (sol_sparse['optimal_intensity'] * plan_sparse.get_num_of_fractions())
x_sparse =sol_sparse['optimal_intensity'] * plan_sparse.get_num_of_fractions()

beams_full = pp.Beams(data, load_inf_matrix_full=True)
inf_matrix_full = pp.InfluenceMatrix(ct=ct, structs=structs, beams=beams_full, is_full=True)
plan_full = pp.Plan(ct, structs, beams, inf_matrix_full, clinical_criteria)
dose_full_1d = plan_full.inf_matrix.A @ (sol_sparse['optimal_intensity'] * plan_full.get_num_of_fractions())

A_dense = plan_full.inf_matrix.A
A_sparse = plan_sparse.inf_matrix.A
# Out:
# creating rinds.. This step may take some time due to dilation
# rinds created!!
# Creating BEV..
# Loading sparse influence matrix...
# Done
# Objective Start
# Objective done
# Constraints Start
# Structure ESOPHAGUS not available!
# Structure ESOPHAGUS not available!
# Constraints done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.1
# ===============================================================================
# (CVXPY) May 29 10:24:04 AM: Your problem has 1946 variables, 14 constraints, and 0 parameters.
# (CVXPY) May 29 10:24:04 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 29 10:24:04 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 29 10:24:04 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 29 10:24:04 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) May 29 10:24:04 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) May 29 10:24:04 AM: Applying reduction Dcp2Cone
# (CVXPY) May 29 10:24:04 AM: Applying reduction CvxAttr2Constr
# (CVXPY) May 29 10:24:04 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 29 10:24:06 AM: Applying reduction MOSEK
# (CVXPY) May 29 10:24:06 AM: Finished problem compilation (took 2.406e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 29 10:24:06 AM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) May 29 10:24:08 AM: Problem
# (CVXPY) May 29 10:24:08 AM:   Name                   :
# (CVXPY) May 29 10:24:08 AM:   Objective sense        : maximize
# (CVXPY) May 29 10:24:08 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) May 29 10:24:08 AM:   Constraints            : 1959
# (CVXPY) May 29 10:24:08 AM:   Affine conic cons.     : 0
# (CVXPY) May 29 10:24:08 AM:   Disjunctive cons.      : 0
# (CVXPY) May 29 10:24:08 AM:   Cones                  : 13
# (CVXPY) May 29 10:24:08 AM:   Scalar variables       : 215748
# (CVXPY) May 29 10:24:08 AM:   Matrix variables       : 0
# (CVXPY) May 29 10:24:08 AM:   Integer variables      : 0
# (CVXPY) May 29 10:24:08 AM:
# (CVXPY) May 29 10:24:08 AM: Optimizer started.
# (CVXPY) May 29 10:24:08 AM: Presolve started.
# (CVXPY) May 29 10:24:09 AM: Linear dependency checker started.
# (CVXPY) May 29 10:24:09 AM: Linear dependency checker terminated.
# (CVXPY) May 29 10:24:09 AM: Eliminator started.
# (CVXPY) May 29 10:24:09 AM: Freed constraints in eliminator : 0
# (CVXPY) May 29 10:24:09 AM: Eliminator terminated.
# (CVXPY) May 29 10:24:09 AM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) May 29 10:24:09 AM: Lin. dep.  - tries                  : 1                 time                   : 0.03
# (CVXPY) May 29 10:24:09 AM: Lin. dep.  - number                 : 0
# (CVXPY) May 29 10:24:09 AM: Presolve terminated. Time: 0.44
# (CVXPY) May 29 10:24:09 AM: Problem
# (CVXPY) May 29 10:24:09 AM:   Name                   :
# (CVXPY) May 29 10:24:09 AM:   Objective sense        : maximize
# (CVXPY) May 29 10:24:09 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) May 29 10:24:09 AM:   Constraints            : 1959
# (CVXPY) May 29 10:24:09 AM:   Affine conic cons.     : 0
# (CVXPY) May 29 10:24:09 AM:   Disjunctive cons.      : 0
# (CVXPY) May 29 10:24:09 AM:   Cones                  : 13
# (CVXPY) May 29 10:24:09 AM:   Scalar variables       : 215748
# (CVXPY) May 29 10:24:09 AM:   Matrix variables       : 0
# (CVXPY) May 29 10:24:09 AM:   Integer variables      : 0
# (CVXPY) May 29 10:24:09 AM:
# (CVXPY) May 29 10:24:09 AM: Optimizer  - threads                : 2
# (CVXPY) May 29 10:24:09 AM: Optimizer  - solved problem         : the primal
# (CVXPY) May 29 10:24:09 AM: Optimizer  - Constraints            : 1959
# (CVXPY) May 29 10:24:09 AM: Optimizer  - Cones                  : 13
# (CVXPY) May 29 10:24:09 AM: Optimizer  - Scalar variables       : 80782             conic                  : 50518
# (CVXPY) May 29 10:24:09 AM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) May 29 10:24:09 AM: Factor     - setup time             : 0.33              dense det. time        : 0.00
# (CVXPY) May 29 10:24:09 AM: Factor     - ML order time          : 0.14              GP order time          : 0.00
# (CVXPY) May 29 10:24:09 AM: Factor     - nonzeros before factor : 2.46e+05          after factor           : 2.47e+05
# (CVXPY) May 29 10:24:09 AM: Factor     - dense dim.             : 4                 flops                  : 8.22e+07
# (CVXPY) May 29 10:24:09 AM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) May 29 10:24:09 AM: 0   1.4e+02  4.6e+02  1.4e+01  0.00e+00   -1.300000000e+01  0.000000000e+00   1.0e+00  1.12
# (CVXPY) May 29 10:24:09 AM: 1   1.2e+02  4.1e+02  1.3e+01  -9.86e-01  4.131473144e+03   4.144316302e+03   8.8e-01  1.27
# (CVXPY) May 29 10:24:09 AM: 2   6.8e+01  2.2e+02  9.5e+00  -9.79e-01  3.094326949e+04   3.095500114e+04   4.8e-01  1.34
# (CVXPY) May 29 10:24:09 AM: 3   3.7e+01  1.2e+02  6.7e+00  -9.13e-01  2.557584936e+04   2.558558020e+04   2.6e-01  1.42
# (CVXPY) May 29 10:24:10 AM: 4   1.4e+01  4.5e+01  3.3e+00  -7.64e-01  1.640479432e+04   1.640934897e+04   9.8e-02  1.50
# (CVXPY) May 29 10:24:10 AM: 5   5.6e+00  1.8e+01  1.3e+00  -3.34e-01  1.093889194e+04   1.093978543e+04   4.0e-02  1.58
# (CVXPY) May 29 10:24:10 AM: 6   2.3e+00  7.5e+00  4.3e-01  1.75e-01   6.846000428e+03   6.845975883e+03   1.6e-02  1.67
# (CVXPY) May 29 10:24:10 AM: 7   8.9e-01  2.9e+00  1.1e-01  5.88e-01   3.360682466e+03   3.360609709e+03   6.3e-03  1.75
# (CVXPY) May 29 10:24:10 AM: 8   3.5e-01  1.2e+00  3.0e-02  8.33e-01   1.471831416e+03   1.471769013e+03   2.5e-03  1.84
# (CVXPY) May 29 10:24:10 AM: 9   1.3e-01  4.4e-01  7.2e-03  9.37e-01   5.963000267e+02   5.962595743e+02   9.5e-04  1.94
# (CVXPY) May 29 10:24:10 AM: 10  5.4e-02  1.8e-01  1.9e-03  9.80e-01   2.794354503e+02   2.794136331e+02   3.8e-04  2.03
# (CVXPY) May 29 10:24:10 AM: 11  1.9e-02  6.3e-02  4.1e-04  9.94e-01   1.242764277e+02   1.242668016e+02   1.4e-04  2.12
# (CVXPY) May 29 10:24:10 AM: 12  7.8e-03  2.5e-02  1.1e-04  1.00e+00   7.813161372e+01   7.812729158e+01   5.5e-05  2.20
# (CVXPY) May 29 10:24:10 AM: 13  2.8e-03  9.1e-03  2.3e-05  1.00e+00   5.422719759e+01   5.422550144e+01   2.0e-05  2.28
# (CVXPY) May 29 10:24:10 AM: 14  1.3e-03  4.1e-03  7.1e-06  1.00e+00   4.690658089e+01   4.690577191e+01   8.9e-06  2.36
# (CVXPY) May 29 10:24:11 AM: 15  4.3e-04  1.4e-03  1.4e-06  9.99e-01   4.377742727e+01   4.377714147e+01   3.0e-06  2.44
# (CVXPY) May 29 10:24:11 AM: 16  1.4e-04  4.7e-04  2.8e-07  9.99e-01   4.262818861e+01   4.262808998e+01   1.0e-06  2.52
# (CVXPY) May 29 10:24:11 AM: 17  6.3e-05  2.1e-04  8.1e-08  9.99e-01   4.229317671e+01   4.229313228e+01   4.5e-07  2.59
# (CVXPY) May 29 10:24:11 AM: 18  1.6e-05  5.2e-05  1.0e-08  1.00e+00   4.210759535e+01   4.210758419e+01   1.1e-07  2.67
# (CVXPY) May 29 10:24:11 AM: 19  2.3e-06  7.4e-06  5.5e-10  1.00e+00   4.205327967e+01   4.205327802e+01   1.6e-08  2.75
# (CVXPY) May 29 10:24:11 AM: 20  8.8e-07  2.9e-06  1.3e-10  9.99e-01   4.204837457e+01   4.204837392e+01   6.2e-09  2.84
# (CVXPY) May 29 10:24:11 AM: 21  3.3e-07  1.1e-06  3.1e-11  1.00e+00   4.204653231e+01   4.204653206e+01   2.3e-09  2.92
# (CVXPY) May 29 10:24:11 AM: 22  9.5e-08  3.1e-07  4.8e-12  9.56e-01   4.204568395e+01   4.204568387e+01   6.6e-10  3.00
# (CVXPY) May 29 10:24:11 AM: 23  7.2e-08  7.8e-08  6.2e-13  1.01e+00   4.204544808e+01   4.204544806e+01   1.7e-10  3.08
# (CVXPY) May 29 10:24:11 AM: Optimizer terminated. Time: 3.16
# (CVXPY) May 29 10:24:11 AM:
# (CVXPY) May 29 10:24:11 AM:
# (CVXPY) May 29 10:24:11 AM: Interior-point solution summary
# (CVXPY) May 29 10:24:11 AM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) May 29 10:24:11 AM:   Solution status : OPTIMAL
# (CVXPY) May 29 10:24:11 AM:   Primal.  obj: 4.2045448085e+01    nrm: 1e+02    Viol.  con: 6e-06    var: 2e-06    cones: 0e+00
# (CVXPY) May 29 10:24:11 AM:   Dual.    obj: 4.2045448063e+01    nrm: 6e+03    Viol.  con: 0e+00    var: 8e-07    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 29 10:24:11 AM: Problem status: optimal
# (CVXPY) May 29 10:24:11 AM: Optimal value: 4.205e+01
# (CVXPY) May 29 10:24:11 AM: Compilation took 2.406e+00 seconds
# (CVXPY) May 29 10:24:11 AM: Solver (including time spent in interface) took 4.855e+00 seconds
# Creating BEV..
# Loading full influence matrix..
# Done
